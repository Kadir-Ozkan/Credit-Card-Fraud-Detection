# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___

# %% [markdown]
# ### Naming Conventions of G2
# 1 - df = dataframe name
# 2 - scaled_df = scalded dataframe name
# 3 - fraud_df = only fraudalent transections part of the dataframe
# 4 - normal_df = non-fraudalent transactions part of the dataframe
# 5 -
# 6 -
# 7 -
# 8 -
# 9 -
# 10 -
# 11 - col = column names of the clean df

# %%
###GitHub Review:
-- Terminali açıyoruz
--önce terminalden repository klasörünü yi indireceğimiz klasöre gidiyoruz (cd ???, ls, cd ?? ls, ..)

git clone https://github.com/Kadir-Ozkan/Credit-Card-Fraud-Detection.git --klasör geldi mi kontrol ediyoruz
git init --klasörün içindeyken


----------make necessary changes-------------------------------


git status -- Gözden kaçan birşey varmı önce kontrol edelim :)

git add Fraud_Detection_G2_8_11_Ver_4.ipynb         

--------Başlamamış olanlar bu dosyadan başlarlarsa daha iyi olur. Başlayan varsa söylesin versiyon 3'e aktaracağım buradakileri---------

git commit -m "?????????"


git remote add origin https://github.com/Kadir-Ozkan/Credit-Card-Fraud-Detection.git

git branch -M main
git push -u origin main

# %% [markdown]
# # WELCOME!

# %% [markdown]
# Welcome to "***Fraud Detection Project***". This is the last project of the Capstone Series.
#
# One of the challenges in this project is the absence of domain knowledge. So without knowing what the column names are, you will only be interested in their values. The other one is the class frequencies of the target variable are quite imbalanced.
#
# You will implement ***Logistic Regression, Random Forest, XGBoost,and Neural Network*** algorithms and ***Unbalanced Data Techniques*** . Also visualize performances of the models using ***Seaborn, Matplotlib*** and ***Yellowbrick*** in a variety of ways.
#
# Data drift and model drirft are key consepts about ML and MLOPS, you can monitor and check your data and models with plenty of ways and tools. ***Deepchecks*** is one of them and the leading tool for testing and for validating your machine learning models and data, and it enables doing so with minimal effort. In this project, you will apply ***Data Integrity, Train-Test Validation, and Model Evaluation*** checks.
# Deepchecks Intruduction : https://youtu.be/7ELdizoi6BU
#
# At the end of the project, you will have the opportunity to deploy your model by ***Streamlit API***.
#
# Before diving into the project, please take a look at the Determines and Tasks.
#
# - ***NOTE:*** *This tutorial assumes that you already know the basics of coding in Python and are familiar with model deployement (Streamlit) as well as the theory behind algorithms*

# %% [markdown]
# ---
# ---

# %% [markdown]
# # #Determines
# The datasets contains transactions made by credit cards in September 2013 by european cardholders. This dataset presents transactions that occurred in two days, where it has **492 frauds** out of **284,807** transactions. The dataset is **highly unbalanced**, the positive class (frauds) account for 0.172% of all transactions.
#
# **Feature Information:**
#
# **Time**: This feature is contains the seconds elapsed between each transaction and the first transaction in the dataset.
#
# **Amount**:  This feature is the transaction Amount, can be used for example-dependant cost-senstive learning.
#
# **Class**: This feature is the target variable and it takes value 1 in case of fraud and 0 otherwise.
#
# ---
#
# The aim of this project is to predict whether a credit card transaction is fraudulent. Of course, this is not easy to do.
# First of all, you need to analyze and recognize your data well in order to draw your roadmap and choose the correct arguments you will use. Accordingly, you can examine the frequency distributions of variables. You can observe variable correlations and want to explore multicollinearity. You can display the distribution of the target variable's classes over other variables.
# Also, it is useful to take missing values and outliers.
#
# After these procedures, you can move on to the model building stage by doing the basic data pre-processing you are familiar with.
#
# Start with Logistic Regression and evaluate model performance. You will apply the Unbalanced Data Techniques used to increase the performance. Next, observe their effects.
#
# Then, you will use four different algorithms in the model building phase.
#
# In the final step, you will deploy your model using ***Streamlit API***.
#
# **Optional**: You can Dockerize your project and deploy on cloud.

# %% [markdown]
# ---
# ---

# %% [markdown]
# # #Tasks
#
# #### 1. Exploratory Data Analysis & Data Cleaning
#
# - Import Modules, Load Data & Data Review
# - Apply data integrity checks
# - Exploratory Data Analysis
# - Data Cleaning
#
# #### 2. Data Preprocessing
#
# - Train - Test Split
# - Train - Test Split Validation Checks
# - Scaling
#
# #### 3. Model Building
#
# - Logistic Regression
# - Random Forest Classifier
# - XGBoost Classifier
# - Neural Network
# -
#
# #### 4. Model Deployement
#
# - Save and Export the Best Model
# - Save and Export Variables

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## 1. Exploratory Data Analysis & Data Cleaning

# %% [markdown]
# ### Import Modules, Load Data & Data Review

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib.ticker as mticker
import plotly.express as px

from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
from sklearn.metrics import make_scorer, precision_score, precision_recall_curve, plot_precision_recall_curve 
from sklearn.metrics import plot_roc_curve, roc_auc_score, roc_curve, f1_score, accuracy_score, recall_score
from sklearn.metrics import silhouette_samples,silhouette_score
from sklearn.model_selection import cross_val_predict, train_test_split
from sklearn.model_selection import StratifiedKFold, GridSearchCV, cross_val_score, cross_validate
from sklearn.pipeline import make_pipeline, Pipeline
from sklearn.preprocessing import MinMaxScaler, scale, StandardScaler, RobustScaler
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
#from xgboost import XGBClassifier, plot_importance

# Ignore Warnings
import warnings
warnings.filterwarnings("ignore")
warnings.warn("this will not show")

# %%
plt.rcParams["figure.figsize"] = (10,6)
pd.set_option('max_colwidth',200)
pd.set_option('display.max_rows', 1000)
pd.set_option('display.max_columns', 200)
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %%
df=pd.read_csv('creditcard.csv')

# %%
"""from google.colab import drive
drive.mount('/content/drive')
df=pd.read_csv('/content/creditcard.csv')"""
# Out:
# "from google.colab import drive\ndrive.mount('/content/drive')\ndf=pd.read_csv('/content/creditcard.csv')"

# %%
# !pip install skimpy
# Out:
# Requirement already satisfied: skimpy in /Users/kadirozkan/tensorflow-metal/lib/python3.9/site-packages (0.0.7)
# Requirement already satisfied: pandas<2.0.0,>=1.3.2 in /Users/kadirozkan/tensorflow-metal/lib/python3.9/site-packages (from skimpy) (1.5.0)
# Requirement already satisfied: numpy<2.0.0,>=1.22.2 in /Users/kadirozkan/tensorflow-metal/lib/python3.9/site-packages (from skimpy) (1.23.3)
# Requirement already satisfied: typeguard<3.0.0,>=2.12.1 in /Users/kadirozkan/tensorflow-metal/lib/python3.9/site-packages (from skimpy) (2.13.3)
# Requirement already satisfied: rich<13.0,>=10.9 in /Users/kadirozkan/tensorflow-metal/lib/python3.9/site-packages (from skimpy) (12.6.0)
# Requirement already satisfied: jupyter<2.0.0,>=1.0.0 in /Users/kadirozkan/tensorflow-metal/lib/python3.9/site-packages (from skimpy) (1.0.0)
# Requirement already satisfied: ipykernel<7.0.0,>=6.7.0 in /Users/kadirozkan/tensorflow-metal/lib/python3.9/site-packages (from skimpy) (6.16.0)
# Requirement already satisfied: Pygments<3.0.0,>=2.10.0 in /Users/kadirozkan/tensorflow-metal/lib/python3.9/site-packages (from skimpy) (2.13.0)
# Requirement already satisfied: click<9.0.0,>=8.1.3 in /Users/kadirozkan/tensorflow-metal/lib/python3.9/site-packages (from skimpy) (8.1.3)
# Requirement already satisfied: jupyter-client>=6.1.12 in /Users/kadirozkan/tensorflow-metal/lib/python3.9/site-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (7.3.5)
# Requirement already satisfied: debugpy>=1.0 in /Users/kadirozkan/tensorflow-metal/lib/python3.9/site-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (1.6.3)
# Requirement already satisfied: ipython>=7.23.1 in /Users/kadirozkan/tensorflow-metal/lib/python3.9/site-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (7.34.0)
# Requirement already satisfied: nest-asyncio in /Users/kadirozkan/tensorflow-metal/lib/python3.9/site-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (1.5.6)
# Requirement already satisfied: pyzmq>=17 in /Users/kadirozkan/tensorflow-metal/lib/python3.9/site-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (23.2.1)
# Requirement already satisfied: appnope in /Users/kadirozkan/tensorflow-metal/lib/python3.9/site-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (0.1.3)
# Requirement already satisfied: packaging in /Users/kadirozkan/tensorflow-metal/lib/python3.9/site-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (21.3)
# Requirement already satisfied: tornado>=6.1 in /Users/kadirozkan/tensorflow-metal/lib/python3.9/site-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (6.2)
# Requirement already satisfied: traitlets>=5.1.0 in /Users/kadirozkan/tensorflow-metal/lib/python3.9/site-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (5.4.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /Users/kadirozkan/tensorflow-metal/lib/python3.9/site-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (0.1.6)
# Requirement already satisfied: psutil in /Users/kadirozkan/tensorflow-metal/lib/python3.9/site-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (5.9.2)
# Requirement already satisfied: jupyter-console in /Users/kadirozkan/tensorflow-metal/lib/python3.9/site-packages (from jupyter<2.0.0,>=1.0.0->skimpy) (6.4.4)
# Requirement already satisfied: notebook in /Users/kadirozkan/tensorflow-metal/lib/python3.9/site-packages (from jupyter<2.0.0,>=1.0.0->skimpy) (6.5.2)
# Requirement already satisfied: nbconvert in /Users/kadirozkan/tensorflow-metal/lib/python3.9/site-packages (from jupyter<2.0.0,>=1.0.0->skimpy) (7.2.3)
# Requirement already satisfied: qtconsole in /Users/kadirozkan/tensorflow-metal/lib/python3.9/site-packages (from jupyter<2.0.0,>=1.0.0->skimpy) (5.4.0)
# Requirement already satisfied: ipywidgets in /Users/kadirozkan/tensorflow-metal/lib/python3.9/site-packages (from jupyter<2.0.0,>=1.0.0->skimpy) (7.7.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/kadirozkan/tensorflow-metal/lib/python3.9/site-packages (from pandas<2.0.0,>=1.3.2->skimpy) (2022.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/kadirozkan/tensorflow-metal/lib/python3.9/site-packages (from pandas<2.0.0,>=1.3.2->skimpy) (2.8.2)
# Requirement already satisfied: commonmark<0.10.0,>=0.9.0 in /Users/kadirozkan/tensorflow-metal/lib/python3.9/site-packages (from rich<13.0,>=10.9->skimpy) (0.9.1)
# Requirement already satisfied: pickleshare in /Users/kadirozkan/tensorflow-metal/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel<7.0.0,>=6.7.0->skimpy) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/kadirozkan/tensorflow-metal/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel<7.0.0,>=6.7.0->skimpy) (3.0.31)
# Requirement already satisfied: decorator in /Users/kadirozkan/tensorflow-metal/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel<7.0.0,>=6.7.0->skimpy) (5.1.1)
# Requirement already satisfied: backcall in /Users/kadirozkan/tensorflow-metal/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel<7.0.0,>=6.7.0->skimpy) (0.2.0)
# Requirement already satisfied: setuptools>=18.5 in /Users/kadirozkan/tensorflow-metal/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel<7.0.0,>=6.7.0->skimpy) (62.3.2)
# Requirement already satisfied: jedi>=0.16 in /Users/kadirozkan/tensorflow-metal/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel<7.0.0,>=6.7.0->skimpy) (0.18.1)
# Requirement already satisfied: pexpect>4.3 in /Users/kadirozkan/tensorflow-metal/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel<7.0.0,>=6.7.0->skimpy) (4.8.0)
# Requirement already satisfied: entrypoints in /Users/kadirozkan/tensorflow-metal/lib/python3.9/site-packages (from jupyter-client>=6.1.12->ipykernel<7.0.0,>=6.7.0->skimpy) (0.4)
# Requirement already satisfied: jupyter-core>=4.9.2 in /Users/kadirozkan/tensorflow-metal/lib/python3.9/site-packages (from jupyter-client>=6.1.12->ipykernel<7.0.0,>=6.7.0->skimpy) (4.11.1)
# Requirement already satisfied: six>=1.5 in /Users/kadirozkan/tensorflow-metal/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas<2.0.0,>=1.3.2->skimpy) (1.16.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /Users/kadirozkan/tensorflow-metal/lib/python3.9/site-packages (from ipywidgets->jupyter<2.0.0,>=1.0.0->skimpy) (3.6.1)
# Requirement already satisfied: jupyterlab-widgets<3,>=1.0.0 in /Users/kadirozkan/tensorflow-metal/lib/python3.9/site-packages (from ipywidgets->jupyter<2.0.0,>=1.0.0->skimpy) (1.1.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /Users/kadirozkan/tensorflow-metal/lib/python3.9/site-packages (from ipywidgets->jupyter<2.0.0,>=1.0.0->skimpy) (0.2.0)
# Requirement already satisfied: markupsafe>=2.0 in /Users/kadirozkan/tensorflow-metal/lib/python3.9/site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->skimpy) (2.1.1)
# Requirement already satisfied: bleach in /Users/kadirozkan/tensorflow-metal/lib/python3.9/site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->skimpy) (5.0.1)
# Requirement already satisfied: jupyterlab-pygments in /Users/kadirozkan/tensorflow-metal/lib/python3.9/site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->skimpy) (0.2.2)
# Requirement already satisfied: importlib-metadata>=3.6 in /Users/kadirozkan/tensorflow-metal/lib/python3.9/site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->skimpy) (5.0.0)
# Requirement already satisfied: beautifulsoup4 in /Users/kadirozkan/tensorflow-metal/lib/python3.9/site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->skimpy) (4.11.1)
# Requirement already satisfied: nbclient>=0.5.0 in /Users/kadirozkan/tensorflow-metal/lib/python3.9/site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->skimpy) (0.7.0)
# Requirement already satisfied: jinja2>=3.0 in /Users/kadirozkan/tensorflow-metal/lib/python3.9/site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->skimpy) (3.1.2)
# Requirement already satisfied: mistune<3,>=2.0.3 in /Users/kadirozkan/tensorflow-metal/lib/python3.9/site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->skimpy) (2.0.4)
# Requirement already satisfied: nbformat>=5.1 in /Users/kadirozkan/tensorflow-metal/lib/python3.9/site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->skimpy) (5.7.0)
# Requirement already satisfied: tinycss2 in /Users/kadirozkan/tensorflow-metal/lib/python3.9/site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->skimpy) (1.2.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/kadirozkan/tensorflow-metal/lib/python3.9/site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->skimpy) (1.5.0)
# Requirement already satisfied: defusedxml in /Users/kadirozkan/tensorflow-metal/lib/python3.9/site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->skimpy) (0.7.1)
# Requirement already satisfied: prometheus-client in /Users/kadirozkan/tensorflow-metal/lib/python3.9/site-packages (from notebook->jupyter<2.0.0,>=1.0.0->skimpy) (0.15.0)
# Requirement already satisfied: argon2-cffi in /Users/kadirozkan/tensorflow-metal/lib/python3.9/site-packages (from notebook->jupyter<2.0.0,>=1.0.0->skimpy) (21.3.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /Users/kadirozkan/tensorflow-metal/lib/python3.9/site-packages (from notebook->jupyter<2.0.0,>=1.0.0->skimpy) (1.8.0)
# Requirement already satisfied: nbclassic>=0.4.7 in /Users/kadirozkan/tensorflow-metal/lib/python3.9/site-packages (from notebook->jupyter<2.0.0,>=1.0.0->skimpy) (0.4.8)
# Requirement already satisfied: terminado>=0.8.3 in /Users/kadirozkan/tensorflow-metal/lib/python3.9/site-packages (from notebook->jupyter<2.0.0,>=1.0.0->skimpy) (0.17.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/kadirozkan/tensorflow-metal/lib/python3.9/site-packages (from packaging->ipykernel<7.0.0,>=6.7.0->skimpy) (3.0.9)
# Requirement already satisfied: qtpy>=2.0.1 in /Users/kadirozkan/tensorflow-metal/lib/python3.9/site-packages (from qtconsole->jupyter<2.0.0,>=1.0.0->skimpy) (2.2.1)
# Requirement already satisfied: zipp>=0.5 in /Users/kadirozkan/tensorflow-metal/lib/python3.9/site-packages (from importlib-metadata>=3.6->nbconvert->jupyter<2.0.0,>=1.0.0->skimpy) (3.8.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/kadirozkan/tensorflow-metal/lib/python3.9/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel<7.0.0,>=6.7.0->skimpy) (0.8.3)
# Requirement already satisfied: jupyter-server>=1.8 in /Users/kadirozkan/tensorflow-metal/lib/python3.9/site-packages (from nbclassic>=0.4.7->notebook->jupyter<2.0.0,>=1.0.0->skimpy) (1.21.0)
# Requirement already satisfied: notebook-shim>=0.1.0 in /Users/kadirozkan/tensorflow-metal/lib/python3.9/site-packages (from nbclassic>=0.4.7->notebook->jupyter<2.0.0,>=1.0.0->skimpy) (0.2.2)
# Requirement already satisfied: jsonschema>=2.6 in /Users/kadirozkan/tensorflow-metal/lib/python3.9/site-packages (from nbformat>=5.1->nbconvert->jupyter<2.0.0,>=1.0.0->skimpy) (4.17.0)
# Requirement already satisfied: fastjsonschema in /Users/kadirozkan/tensorflow-metal/lib/python3.9/site-packages (from nbformat>=5.1->nbconvert->jupyter<2.0.0,>=1.0.0->skimpy) (2.16.2)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/kadirozkan/tensorflow-metal/lib/python3.9/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel<7.0.0,>=6.7.0->skimpy) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/kadirozkan/tensorflow-metal/lib/python3.9/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=7.23.1->ipykernel<7.0.0,>=6.7.0->skimpy) (0.2.5)
# Requirement already satisfied: argon2-cffi-bindings in /Users/kadirozkan/tensorflow-metal/lib/python3.9/site-packages (from argon2-cffi->notebook->jupyter<2.0.0,>=1.0.0->skimpy) (21.2.0)
# Requirement already satisfied: soupsieve>1.2 in /Users/kadirozkan/tensorflow-metal/lib/python3.9/site-packages (from beautifulsoup4->nbconvert->jupyter<2.0.0,>=1.0.0->skimpy) (2.3.2.post1)
# Requirement already satisfied: webencodings in /Users/kadirozkan/tensorflow-metal/lib/python3.9/site-packages (from bleach->nbconvert->jupyter<2.0.0,>=1.0.0->skimpy) (0.5.1)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /Users/kadirozkan/tensorflow-metal/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert->jupyter<2.0.0,>=1.0.0->skimpy) (0.19.2)
# Requirement already satisfied: attrs>=17.4.0 in /Users/kadirozkan/tensorflow-metal/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert->jupyter<2.0.0,>=1.0.0->skimpy) (22.1.0)
# Requirement already satisfied: anyio<4,>=3.1.0 in /Users/kadirozkan/tensorflow-metal/lib/python3.9/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter<2.0.0,>=1.0.0->skimpy) (3.6.2)
# Requirement already satisfied: websocket-client in /Users/kadirozkan/tensorflow-metal/lib/python3.9/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter<2.0.0,>=1.0.0->skimpy) (1.4.2)
# Requirement already satisfied: cffi>=1.0.1 in /Users/kadirozkan/tensorflow-metal/lib/python3.9/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook->jupyter<2.0.0,>=1.0.0->skimpy) (1.15.1)
# Requirement already satisfied: idna>=2.8 in /Users/kadirozkan/tensorflow-metal/lib/python3.9/site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter<2.0.0,>=1.0.0->skimpy) (3.4)
# Requirement already satisfied: sniffio>=1.1 in /Users/kadirozkan/tensorflow-metal/lib/python3.9/site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter<2.0.0,>=1.0.0->skimpy) (1.3.0)
# Requirement already satisfied: pycparser in /Users/kadirozkan/tensorflow-metal/lib/python3.9/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook->jupyter<2.0.0,>=1.0.0->skimpy) (2.21)

# %%
from skimpy import clean_columns
df = clean_columns(df)
# Out:
# 31 column names have been cleaned

# %%
df
# Out:
#              time     v_1    v_2    v_3    v_4    v_5    v_6    v_7    v_8  \
# 0           0.000  -1.360 -0.073  2.536  1.378 -0.338  0.462  0.240  0.099
# 1           0.000   1.192  0.266  0.166  0.448  0.060 -0.082 -0.079  0.085
# 2           1.000  -1.358 -1.340  1.773  0.380 -0.503  1.800  0.791  0.248
# 3           1.000  -0.966 -0.185  1.793 -0.863 -0.010  1.247  0.238  0.377
# 4           2.000  -1.158  0.878  1.549  0.403 -0.407  0.096  0.593 -0.271
# ...           ...     ...    ...    ...    ...    ...    ...    ...    ...
# 284802 172786.000 -11.881 10.072 -9.835 -2.067 -5.364 -2.607 -4.918  7.305
# 284803 172787.000  -0.733 -0.055  2.035 -0.739  0.868  1.058  0.024  0.295
# 284804 172788.000   1.920 -0.301 -3.250 -0.558  2.631  3.031 -0.297  0.708
# 284805 172788.000  -0.240  0.530  0.703  0.690 -0.378  0.624 -0.686  0.679
# 284806 172792.000  -0.533 -0.190  0.703 -0.506 -0.013 -0.650  1.577 -0.415
#
#           v_9   v_10   v_11   v_12   v_13   v_14   v_15   v_16   v_17   v_18  \
# 0       0.364  0.091 -0.552 -0.618 -0.991 -0.311  1.468 -0.470  0.208  0.026
# 1      -0.255 -0.167  1.613  1.065  0.489 -0.144  0.636  0.464 -0.115 -0.183
# 2      -1.515  0.208  0.625  0.066  0.717 -0.166  2.346 -2.890  1.110 -0.121
# 3      -1.387 -0.055 -0.226  0.178  0.508 -0.288 -0.631 -1.060 -0.684  1.966
# 4       0.818  0.753 -0.823  0.538  1.346 -1.120  0.175 -0.451 -0.237 -0.038
# ...       ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 284802  1.914  4.356 -1.593  2.712 -0.689  4.627 -0.924  1.108  1.992  0.511
# 284803  0.585 -0.976 -0.150  0.916  1.215 -0.675  1.165 -0.712 -0.026 -1.221
# 284804  0.432 -0.485  0.412  0.063 -0.184 -0.511  1.329  0.141  0.314  0.396
# 284805  0.392 -0.399 -1.934 -0.963 -1.042  0.450  1.963 -0.609  0.510  1.114
# 284806  0.486 -0.915 -1.040 -0.032 -0.188 -0.084  0.041 -0.303 -0.660  0.167
#
#          v_19   v_20   v_21   v_22   v_23   v_24   v_25   v_26   v_27   v_28  \
# 0       0.404  0.251 -0.018  0.278 -0.110  0.067  0.129 -0.189  0.134 -0.021
# 1      -0.146 -0.069 -0.226 -0.639  0.101 -0.340  0.167  0.126 -0.009  0.015
# 2      -2.262  0.525  0.248  0.772  0.909 -0.689 -0.328 -0.139 -0.055 -0.060
# 3      -1.233 -0.208 -0.108  0.005 -0.190 -1.176  0.647 -0.222  0.063  0.061
# 4       0.803  0.409 -0.009  0.798 -0.137  0.141 -0.206  0.502  0.219  0.215
# ...       ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 284802 -0.683  1.476  0.213  0.112  1.014 -0.509  1.437  0.250  0.944  0.824
# 284803 -1.546  0.060  0.214  0.924  0.012 -1.016 -0.607 -0.395  0.068 -0.054
# 284804 -0.577  0.001  0.232  0.578 -0.038  0.640  0.266 -0.087  0.004 -0.027
# 284805  2.898  0.127  0.265  0.800 -0.163  0.123 -0.569  0.547  0.109  0.105
# 284806 -0.256  0.383  0.261  0.643  0.377  0.009 -0.474 -0.818 -0.002  0.014
#
#         amount  class
# 0      149.620      0
# 1        2.690      0
# 2      378.660      0
# 3      123.500      0
# 4       69.990      0
# ...        ...    ...
# 284802   0.770      0
# 284803  24.790      0
# 284804  67.880      0
# 284805  10.000      0
# 284806 217.000      0
#
# [284807 rows x 31 columns]

# %%
df.head()
# Out:
#    time    v_1    v_2   v_3    v_4    v_5    v_6    v_7    v_8    v_9   v_10  \
# 0 0.000 -1.360 -0.073 2.536  1.378 -0.338  0.462  0.240  0.099  0.364  0.091
# 1 0.000  1.192  0.266 0.166  0.448  0.060 -0.082 -0.079  0.085 -0.255 -0.167
# 2 1.000 -1.358 -1.340 1.773  0.380 -0.503  1.800  0.791  0.248 -1.515  0.208
# 3 1.000 -0.966 -0.185 1.793 -0.863 -0.010  1.247  0.238  0.377 -1.387 -0.055
# 4 2.000 -1.158  0.878 1.549  0.403 -0.407  0.096  0.593 -0.271  0.818  0.753
#
#     v_11   v_12   v_13   v_14   v_15   v_16   v_17   v_18   v_19   v_20  \
# 0 -0.552 -0.618 -0.991 -0.311  1.468 -0.470  0.208  0.026  0.404  0.251
# 1  1.613  1.065  0.489 -0.144  0.636  0.464 -0.115 -0.183 -0.146 -0.069
# 2  0.625  0.066  0.717 -0.166  2.346 -2.890  1.110 -0.121 -2.262  0.525
# 3 -0.226  0.178  0.508 -0.288 -0.631 -1.060 -0.684  1.966 -1.233 -0.208
# 4 -0.823  0.538  1.346 -1.120  0.175 -0.451 -0.237 -0.038  0.803  0.409
#
#     v_21   v_22   v_23   v_24   v_25   v_26   v_27   v_28  amount  class
# 0 -0.018  0.278 -0.110  0.067  0.129 -0.189  0.134 -0.021 149.620      0
# 1 -0.226 -0.639  0.101 -0.340  0.167  0.126 -0.009  0.015   2.690      0
# 2  0.248  0.772  0.909 -0.689 -0.328 -0.139 -0.055 -0.060 378.660      0
# 3 -0.108  0.005 -0.190 -1.176  0.647 -0.222  0.063  0.061 123.500      0
# 4 -0.009  0.798 -0.137  0.141 -0.206  0.502  0.219  0.215  69.990      0

# %%
df.columns
# Out:
# Index(['time', 'v_1', 'v_2', 'v_3', 'v_4', 'v_5', 'v_6', 'v_7', 'v_8', 'v_9',
#        'v_10', 'v_11', 'v_12', 'v_13', 'v_14', 'v_15', 'v_16', 'v_17', 'v_18',
#        'v_19', 'v_20', 'v_21', 'v_22', 'v_23', 'v_24', 'v_25', 'v_26', 'v_27',
#        'v_28', 'amount', 'class'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   time    284807 non-null  float64
#  1   v_1     284807 non-null  float64
#  2   v_2     284807 non-null  float64
#  3   v_3     284807 non-null  float64
#  4   v_4     284807 non-null  float64
#  5   v_5     284807 non-null  float64
#  6   v_6     284807 non-null  float64
#  7   v_7     284807 non-null  float64
#  8   v_8     284807 non-null  float64
#  9   v_9     284807 non-null  float64
#  10  v_10    284807 non-null  float64
#  11  v_11    284807 non-null  float64
#  12  v_12    284807 non-null  float64
#  13  v_13    284807 non-null  float64
#  14  v_14    284807 non-null  float64
#  15  v_15    284807 non-null  float64
#  16  v_16    284807 non-null  float64
#  17  v_17    284807 non-null  float64
#  18  v_18    284807 non-null  float64
#  19  v_19    284807 non-null  float64
#  20  v_20    284807 non-null  float64
#  21  v_21    284807 non-null  float64
#  22  v_22    284807 non-null  float64
#  23  v_23    284807 non-null  float64
#  24  v_24    284807 non-null  float64
#  25  v_25    284807 non-null  float64
#  26  v_26    284807 non-null  float64
#  27  v_27    284807 non-null  float64
#  28  v_28    284807 non-null  float64
#  29  amount  284807 non-null  float64
#  30  class   284807 non-null  int64
# dtypes: float64(30), int64(1)
# memory usage: 67.4 MB

# %%
col=(['satisfaction_level', 'last_evaluation', 'number_project',
       'average_montly_hours', 'time_spend_company', 'work_accident', 'left',
       'promotion_last_5years', 'departments', 'salary'])

# %%
Num_of_Uniques=df.nunique()
Num_of_Uniques
# Out:
# time      124592
# v_1       275663
# v_2       275663
# v_3       275663
# v_4       275663
# v_5       275663
# v_6       275663
# v_7       275663
# v_8       275663
# v_9       275663
# v_10      275663
# v_11      275663
# v_12      275663
# v_13      275663
# v_14      275663
# v_15      275663
# v_16      275663
# v_17      275663
# v_18      275663
# v_19      275663
# v_20      275663
# v_21      275663
# v_22      275663
# v_23      275663
# v_24      275663
# v_25      275663
# v_26      275663
# v_27      275663
# v_28      275663
# amount     32767
# class          2
# dtype: int64

# %%
df.shape
# Out:
# (284807, 31)

# %% [markdown]
# ### Data Cleaning
# Check Missing Values and Outliers

# %%
Num_of_Nulls = df.isnull().sum()
Num_of_Nulls
# Out:
# time      0
# v_1       0
# v_2       0
# v_3       0
# v_4       0
# v_5       0
# v_6       0
# v_7       0
# v_8       0
# v_9       0
# v_10      0
# v_11      0
# v_12      0
# v_13      0
# v_14      0
# v_15      0
# v_16      0
# v_17      0
# v_18      0
# v_19      0
# v_20      0
# v_21      0
# v_22      0
# v_23      0
# v_24      0
# v_25      0
# v_26      0
# v_27      0
# v_28      0
# amount    0
# class     0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 1081

# %%
fraud = df[df['class'] == 1].duplicated().sum()
fraud
# Out:
# 19

# %%
percentage = fraud/len(df[df['class'] == 1])*100
percentage
# Out:
# 3.861788617886179

# %%
df=df.drop_duplicates()

# %%
df.shape
# Out:
# (283726, 31)

# %% [markdown]
# ### Exploratory Data Analysis

# %%
df.describe().T.style.background_gradient(cmap='RdYlGn', axis=1)
# Out:
# <style type="text/css">
# #T_f9604_row0_col0, #T_f9604_row1_col0, #T_f9604_row2_col0, #T_f9604_row3_col0, #T_f9604_row4_col0, #T_f9604_row5_col0, #T_f9604_row6_col0, #T_f9604_row7_col0, #T_f9604_row8_col0, #T_f9604_row9_col0, #T_f9604_row10_col0, #T_f9604_row11_col0, #T_f9604_row12_col0, #T_f9604_row13_col0, #T_f9604_row14_col0, #T_f9604_row15_col0, #T_f9604_row16_col0, #T_f9604_row17_col0, #T_f9604_row18_col0, #T_f9604_row19_col0, #T_f9604_row20_col0, #T_f9604_row21_col0, #T_f9604_row22_col0, #T_f9604_row23_col0, #T_f9604_row24_col0, #T_f9604_row25_col0, #T_f9604_row26_col0, #T_f9604_row27_col0, #T_f9604_row28_col0, #T_f9604_row29_col0, #T_f9604_row30_col0 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_f9604_row0_col1 {
#   background-color: #fdbf6f;
#   color: #000000;
# }
# #T_f9604_row0_col2 {
#   background-color: #ea5739;
#   color: #f1f1f1;
# }
# #T_f9604_row0_col3, #T_f9604_row1_col1, #T_f9604_row1_col2, #T_f9604_row1_col3, #T_f9604_row1_col4, #T_f9604_row1_col5, #T_f9604_row1_col6, #T_f9604_row1_col7, #T_f9604_row2_col1, #T_f9604_row2_col2, #T_f9604_row2_col3, #T_f9604_row2_col4, #T_f9604_row2_col5, #T_f9604_row2_col6, #T_f9604_row2_col7, #T_f9604_row3_col1, #T_f9604_row3_col2, #T_f9604_row3_col3, #T_f9604_row3_col4, #T_f9604_row3_col5, #T_f9604_row3_col6, #T_f9604_row3_col7, #T_f9604_row4_col1, #T_f9604_row4_col2, #T_f9604_row4_col3, #T_f9604_row4_col4, #T_f9604_row4_col5, #T_f9604_row4_col6, #T_f9604_row4_col7, #T_f9604_row5_col1, #T_f9604_row5_col2, #T_f9604_row5_col3, #T_f9604_row5_col4, #T_f9604_row5_col5, #T_f9604_row5_col6, #T_f9604_row5_col7, #T_f9604_row6_col1, #T_f9604_row6_col2, #T_f9604_row6_col3, #T_f9604_row6_col4, #T_f9604_row6_col5, #T_f9604_row6_col6, #T_f9604_row6_col7, #T_f9604_row7_col1, #T_f9604_row7_col2, #T_f9604_row7_col3, #T_f9604_row7_col4, #T_f9604_row7_col5, #T_f9604_row7_col6, #T_f9604_row7_col7, #T_f9604_row8_col1, #T_f9604_row8_col2, #T_f9604_row8_col3, #T_f9604_row8_col4, #T_f9604_row8_col5, #T_f9604_row8_col6, #T_f9604_row8_col7, #T_f9604_row9_col1, #T_f9604_row9_col2, #T_f9604_row9_col3, #T_f9604_row9_col4, #T_f9604_row9_col5, #T_f9604_row9_col6, #T_f9604_row9_col7, #T_f9604_row10_col1, #T_f9604_row10_col2, #T_f9604_row10_col3, #T_f9604_row10_col4, #T_f9604_row10_col5, #T_f9604_row10_col6, #T_f9604_row10_col7, #T_f9604_row11_col1, #T_f9604_row11_col2, #T_f9604_row11_col3, #T_f9604_row11_col4, #T_f9604_row11_col5, #T_f9604_row11_col6, #T_f9604_row11_col7, #T_f9604_row12_col1, #T_f9604_row12_col2, #T_f9604_row12_col3, #T_f9604_row12_col4, #T_f9604_row12_col5, #T_f9604_row12_col6, #T_f9604_row12_col7, #T_f9604_row13_col1, #T_f9604_row13_col2, #T_f9604_row13_col3, #T_f9604_row13_col4, #T_f9604_row13_col5, #T_f9604_row13_col6, #T_f9604_row13_col7, #T_f9604_row14_col1, #T_f9604_row14_col2, #T_f9604_row14_col3, #T_f9604_row14_col4, #T_f9604_row14_col5, #T_f9604_row14_col6, #T_f9604_row14_col7, #T_f9604_row15_col1, #T_f9604_row15_col2, #T_f9604_row15_col3, #T_f9604_row15_col4, #T_f9604_row15_col5, #T_f9604_row15_col6, #T_f9604_row15_col7, #T_f9604_row16_col1, #T_f9604_row16_col2, #T_f9604_row16_col3, #T_f9604_row16_col4, #T_f9604_row16_col5, #T_f9604_row16_col6, #T_f9604_row16_col7, #T_f9604_row17_col1, #T_f9604_row17_col2, #T_f9604_row17_col3, #T_f9604_row17_col4, #T_f9604_row17_col5, #T_f9604_row17_col6, #T_f9604_row17_col7, #T_f9604_row18_col1, #T_f9604_row18_col2, #T_f9604_row18_col3, #T_f9604_row18_col4, #T_f9604_row18_col5, #T_f9604_row18_col6, #T_f9604_row18_col7, #T_f9604_row19_col1, #T_f9604_row19_col2, #T_f9604_row19_col3, #T_f9604_row19_col4, #T_f9604_row19_col5, #T_f9604_row19_col6, #T_f9604_row19_col7, #T_f9604_row20_col1, #T_f9604_row20_col2, #T_f9604_row20_col3, #T_f9604_row20_col4, #T_f9604_row20_col5, #T_f9604_row20_col6, #T_f9604_row20_col7, #T_f9604_row21_col1, #T_f9604_row21_col2, #T_f9604_row21_col3, #T_f9604_row21_col4, #T_f9604_row21_col5, #T_f9604_row21_col6, #T_f9604_row21_col7, #T_f9604_row22_col1, #T_f9604_row22_col2, #T_f9604_row22_col3, #T_f9604_row22_col4, #T_f9604_row22_col5, #T_f9604_row22_col6, #T_f9604_row22_col7, #T_f9604_row23_col1, #T_f9604_row23_col2, #T_f9604_row23_col3, #T_f9604_row23_col4, #T_f9604_row23_col5, #T_f9604_row23_col6, #T_f9604_row23_col7, #T_f9604_row24_col1, #T_f9604_row24_col2, #T_f9604_row24_col3, #T_f9604_row24_col4, #T_f9604_row24_col5, #T_f9604_row24_col6, #T_f9604_row24_col7, #T_f9604_row25_col1, #T_f9604_row25_col2, #T_f9604_row25_col3, #T_f9604_row25_col4, #T_f9604_row25_col5, #T_f9604_row25_col6, #T_f9604_row25_col7, #T_f9604_row26_col1, #T_f9604_row26_col2, #T_f9604_row26_col3, #T_f9604_row26_col4, #T_f9604_row26_col5, #T_f9604_row26_col6, #T_f9604_row26_col7, #T_f9604_row27_col1, #T_f9604_row27_col2, #T_f9604_row27_col3, #T_f9604_row27_col4, #T_f9604_row27_col5, #T_f9604_row27_col6, #T_f9604_row27_col7, #T_f9604_row28_col1, #T_f9604_row28_col2, #T_f9604_row28_col3, #T_f9604_ro ...
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_f9604_row0_col4 {
#   background-color: #f16640;
#   color: #f1f1f1;
# }
# #T_f9604_row0_col5 {
#   background-color: #fdad60;
#   color: #000000;
# }
# #T_f9604_row0_col6 {
#   background-color: #fffcba;
#   color: #000000;
# }
# #T_f9604_row0_col7 {
#   background-color: #d5ed88;
#   color: #000000;
# }
# #T_f9604_row29_col7 {
#   background-color: #d22b27;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_f9604">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f9604_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_f9604_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_f9604_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_f9604_level0_col3" class="col_heading level0 col3" >min</th>
#       <th id="T_f9604_level0_col4" class="col_heading level0 col4" >25%</th>
#       <th id="T_f9604_level0_col5" class="col_heading level0 col5" >50%</th>
#       <th id="T_f9604_level0_col6" class="col_heading level0 col6" >75%</th>
#       <th id="T_f9604_level0_col7" class="col_heading level0 col7" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f9604_level0_row0" class="row_heading level0 row0" >time</th>
#       <td id="T_f9604_row0_col0" class="data row0 col0" >283726.000000</td>
#       <td id="T_f9604_row0_col1" class="data row0 col1" >94811.077600</td>
#       <td id="T_f9604_row0_col2" class="data row0 col2" >47481.047891</td>
#       <td id="T_f9604_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_f9604_row0_col4" class="data row0 col4" >54204.750000</td>
#       <td id="T_f9604_row0_col5" class="data row0 col5" >84692.500000</td>
#       <td id="T_f9604_row0_col6" class="data row0 col6" >139298.000000</td>
#       <td id="T_f9604_row0_col7" class="data row0 col7" >172792.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f9604_level0_row1" class="row_heading level0 row1" >v_1</th>
#       <td id="T_f9604_row1_col0" class="data row1 col0" >283726.000000</td>
#       <td id="T_f9604_row1_col1" class="data row1 col1" >0.005917</td>
#       <td id="T_f9604_row1_col2" class="data row1 col2" >1.948026</td>
#       <td id="T_f9604_row1_col3" class="data row1 col3" >-56.407510</td>
#       <td id="T_f9604_row1_col4" class="data row1 col4" >-0.915951</td>
#       <td id="T_f9604_row1_col5" class="data row1 col5" >0.020384</td>
#       <td id="T_f9604_row1_col6" class="data row1 col6" >1.316068</td>
#       <td id="T_f9604_row1_col7" class="data row1 col7" >2.454930</td>
#     </tr>
#     <tr>
#       <th id="T_f9604_level0_row2" class="row_heading level0 row2" >v_2</th>
#       <td id="T_f9604_row2_col0" class="data row2 col0" >283726.000000</td>
#       <td id="T_f9604_row2_col1" class="data row2 col1" >-0.004135</td>
#       <td id="T_f9604_row2_col2" class="data row2 col

# %%
df.groupby('class').describe()
# Out:
#             time                                                             \
#            count      mean       std     min       25%       50%        75%
# class
# 0     283253.000 94835.058 47475.551   0.000 54233.000 84711.000 139308.000
# 1        473.000 80450.514 48636.180 406.000 41203.000 73408.000 129095.000
#
#                         v_1                                                  \
#              max      count   mean   std     min    25%    50%    75%   max
# class
# 0     172792.000 283253.000  0.013 1.922 -56.408 -0.913  0.023  1.317 2.455
# 1     170348.000    473.000 -4.498 6.593 -30.552 -5.604 -2.272 -0.361 2.132
#
#              v_2                                                       v_3  \
#            count   mean   std     min    25%   50%   75%    max      count
# class
# 0     283253.000 -0.010 1.634 -72.716 -0.601 0.063 0.797 18.902 283253.000
# 1        473.000  3.406 4.123  -8.402  1.145 2.617 4.572 22.058    473.000
#
#                                                              v_4               \
#         mean   std     min    25%    50%    75%   max      count   mean   std
# class
# 0      0.013 1.458 -48.326 -0.884  0.182  1.028 9.383 283253.000 -0.010 1.399
# 1     -6.730 6.910 -31.104 -7.927 -4.875 -2.171 2.250    473.000  4.473 2.872
#
#                                                v_5                        \
#          min    25%    50%   75%    max      count   mean   std      min
# class
# 0     -5.683 -0.852 -0.024 0.734 16.875 283253.000  0.007 1.356 -113.743
# 1     -1.313  2.289  4.100 6.291 12.115    473.000 -2.957 5.279  -22.106
#
#                                         v_6                              \
#          25%    50%   75%    max      count   mean   std     min    25%
# class
# 0     -0.688 -0.053 0.612 34.802 283253.000  0.001 1.330 -26.161 -0.768
# 1     -4.279 -1.372 0.261 11.095    473.000 -1.433 1.715  -6.406 -2.450
#
#                                   v_7                                     \
#          50%    75%    max      count   mean   std     min    25%    50%
# class
# 0     -0.274  0.398 73.302 283253.000  0.010 1.177 -31.765 -0.550  0.042
# 1     -1.420 -0.414  6.474    473.000 -5.176 6.858 -43.557 -6.989 -2.902
#
#                             v_8                                          \
#          75%     max      count   mean   std     min    25%   50%   75%
# class
# 0      0.571 120.589 283253.000 -0.002 1.157 -73.217 -0.209 0.022 0.324
# 1     -0.907   5.803    473.000  0.953 5.586 -41.044 -0.162 0.618 1.709
#
#                     v_9                                                   \
#          max      count   mean   std     min    25%    50%    75%    max
# class
# 0     18.709 283253.000  0.003 1.087  -6.291 -0.642 -0.051  0.597 15.595
# 1     20.007    473.000 -2.522 2.465 -13.434 -3.797 -2.099 -0.788  3.354
#
#             v_10                                                        v_11  \
#            count   mean   std     min    25%    50%    75%    max      count
# class
# 0     283253.000  0.008 1.036 -14.741 -0.533 -0.092  0.455 23.745 283253.000
# 1        473.000 -5.453 4.706 -24.588 -7.298 -4.466 -2.447  4.031    473.000
#
#                                                            v_12               \
#         mean   std    min    25%    50%   75%    max      count   mean   std
# class
# 0     -0.006 1.002 -4.797 -0.763 -0.034 0.737 10.002 283253.000  0.009 0.945
# 1      3.716 2.673 -1.702  1.929  3.526 5.224 12.019    473.000 -6.103 4.582
#
#                ...    v_17                           v_18                      \
#           min  ...     25%    50%    75%   max      count   mean   std    min
# class          ...
# 0     -15.145  ...  -0.483 -0.065  0.399 9.254 283253.000  0.005 0.825 -5.367
# 1     -18.684  ... -11.589 -5.158 -1.129 6.739    473.000 -2.157 2.902 -9.499
#
#                                       v_19                                   \
#          25%    50%   75%   max      count   mean   std    min    25%   50%
# class
# 0     -0.497 -0.001 0.502 5.041 283253.000 -0.001 0.811 -7.214 -0.456 0.003
# 1     -4.569 -1.418 0.116 3.790    473.000  0.669 1.534 -3.682 -0.301 0.648
#
#                         v_20                                                  \
#         75%   max      count   mean   std     min    25%    50%   75%    max
# class
# 0     0.457 5.592 283253.000 -0.000 0.769 -54.498 -0.212 -0.063 0.133 39.421
# 1     1.661 5.228    473.000  0.405 1.289  -4.128 -0.160  0.286 0.821 11.059
#
#             v_21                                                       v_22  \
#            count   mean   std     min    25%    50%   75%    max      count
# class
# 0     283253.000 -0.001 0.716 -34.830 -0.228 -0.030 0.185 22.615 283253.000
# 1        473.000  0.467 2.731 -22.798  0.028  0.574 1.193 27.203    473.000
#
#                                                            v_23               \
#         mean   std     min    25%   50%   75%    max      count   mean   std
# class
# 0     -0.000 0.724 -10.933 -0.543 0.007 0.528 10.503 283253.000  0.000 0.621
# 1      0.087 1.181  -8.887 -0.522 0.055 0.616  8.362    473.000 -0.096 1.509
#
#                                                v_24                      \
#           min    25%    50%   75%    max      count   mean   std    min
# class
# 0     -44.808 -0.161 -0.011 0.148 22.528 283253.000  0.000 0.606 -2.837
# 1     -19.254 -0.342 -0.075 0.288  5.466    473.000 -0.107 0.518 -2.028
#
#                                       v_25                                    \
#          25%    50%   75%   max      count   mean   std     min    25%   50%
# class
# 0     -0.354  0.041 0.440 4.585 283253.000 -0.000 0.521 -10.295 -0.317 0.016
# 1     -0.437 -0.061 0.282 1.091    473.000  0.041 0.807  -4.782 -0.320 0.078
#
#                         v_26                                               \
#         75%   max      count  mean   std    min    25%    50%   75%   max
# class
# 0     0.350 7.520 283253.000 0.000 0.482 -2.605 -0.327 -0.052 0.240 3.517
# 1     0.464 2.208    473.000 0.050 0.463 -1.153 -0.263  0.013 0.396 2.745
#
#             v_27                                                     v_28  \
#            count  mean   std     min    25%   50%   75%    max      count
# class
# 0     283253.000 0.001 0.393 -22.566 -0.071 0.001 0.091 31.612 283253.000
# 1        473.000 0.214 1.246  -7.263 -0.016 0.395 0.821  3.052    473.000
#
#                                                         amount          \
#        mean   std     min    25%   50%   75%    max      count    mean
# class
# 0     0.000 0.328 -15.430 -0.053 0.011 0.078 33.848 283253.000  88.414
# 1     0.078 0.533  -1.869 -0.097 0.146 0.372  1.779    473.000 123.872
#
#
#           std   min   25%    50%     75%       max
# class
# 0     250.379 0.000 5.670 22.000  77.460 25691.160
# 1     260.211 0.000 1.000  9.820 105.890  2125.870
#
# [2 rows x 240 columns]

# %%
df["class"].value_counts(normalize=True)
# Out:
# 0   0.998
# 1   0.002
# Name: class, dtype: float64

# %%
from colorama import Fore, Back, Style
def first_looking(col):
    """give only column name as "col_name" not as df["col_name"]"""
    print(Back.BLACK + Fore.YELLOW, "Column name    : ", col, Style.RESET_ALL)
    print(Fore.RED + "--------------------------------", Style.RESET_ALL)
    print("per_of_nulls   : ", "%", round(df[col].isnull().sum()*100 / df.shape[0], 2))
    print("num_of_nulls   : ", df[col].isnull().sum())
    print("num_of_uniques : ", df[col].nunique())
    print(Fore.RED + "--------------------------------", Style.RESET_ALL)
    print("Value counts")
    print(df[col].value_counts(dropna = False))
    print(Fore.RED + "--------------------------------", Style.RESET_ALL)
    print("Descriptive statistics")
    print(df[col].describe())
    print()
    print()

# %%
first_looking("time")
# Out:
#  Column name    :  time
# --------------------------------
# per_of_nulls   :  % 0.0
# num_of_nulls   :  0
# num_of_uniques :  124592
# --------------------------------
# Value counts
# 3767.000      21
# 3770.000      20
# 19912.000     19
# 3750.000      19
# 73885.000     17
#               ..
# 127732.000     1
# 62217.000      1
# 127739.000     1
# 127741.000     1
# 172792.000     1
# Name: time, Length: 124592, dtype: int64
# --------------------------------
# Descriptive statistics
# count   283726.000
# mean     94811.078
# std      47481.048
# min          0.000
# 25%      54204.750
# 50%      84692.500
# 75%     139298.000
# max     172792.000
# Name: time, dtype: float64

# %%
first_looking("amount")
# Out:
#  Column name    :  amount
# --------------------------------
# per_of_nulls   :  % 0.0
# num_of_nulls   :  0
# num_of_uniques :  32767
# --------------------------------
# Value counts
# 1.000      13566
# 1.980       6044
# 0.890       4871
# 9.990       4738
# 15.000      3280
#            ...
# 526.600        1
# 248.160        1
# 492.650        1
# 811.500        1
# 95.630         1
# Name: amount, Length: 32767, dtype: int64
# --------------------------------
# Descriptive statistics
# count   283726.000
# mean        88.473
# std        250.399
# min          0.000
# 25%          5.600
# 50%         22.000
# 75%         77.510
# max      25691.160
# Name: amount, dtype: float64

# %%
first_looking("class")
# Out:
#  Column name    :  class
# --------------------------------
# per_of_nulls   :  % 0.0
# num_of_nulls   :  0
# num_of_uniques :  2
# --------------------------------
# Value counts
# 0    283253
# 1       473
# Name: class, dtype: int64
# --------------------------------
# Descriptive statistics
# count   283726.000
# mean         0.002
# std          0.041
# min          0.000
# 25%          0.000
# 50%          0.000
# 75%          0.000
# max          1.000
# Name: class, dtype: float64

# %%
df[df['class'] == 1].describe()
# Out:
#             time     v_1     v_2     v_3     v_4     v_5     v_6     v_7  \
# count    473.000 473.000 473.000 473.000 473.000 473.000 473.000 473.000
# mean   80450.514  -4.498   3.406  -6.730   4.473  -2.957  -1.433  -5.176
# std    48636.180   6.593   4.123   6.910   2.872   5.279   1.715   6.858
# min      406.000 -30.552  -8.402 -31.104  -1.313 -22.106  -6.406 -43.557
# 25%    41203.000  -5.604   1.145  -7.927   2.289  -4.279  -2.450  -6.989
# 50%    73408.000  -2.272   2.617  -4.875   4.100  -1.372  -1.420  -2.902
# 75%   129095.000  -0.361   4.572  -2.171   6.291   0.261  -0.414  -0.907
# max   170348.000   2.132  22.058   2.250  12.115  11.095   6.474   5.803
#
#           v_8     v_9    v_10    v_11    v_12    v_13    v_14    v_15    v_16  \
# count 473.000 473.000 473.000 473.000 473.000 473.000 473.000 473.000 473.000
# mean    0.953  -2.522  -5.453   3.716  -6.103  -0.094  -6.836  -0.073  -4.001
# std     5.586   2.465   4.706   2.673   4.582   1.108   4.253   1.046   3.832
# min   -41.044 -13.434 -24.588  -1.702 -18.684  -3.128 -19.214  -4.499 -14.130
# 25%    -0.162  -3.797  -7.298   1.929  -8.602  -0.978  -9.505  -0.638  -6.469
# 50%     0.618  -2.099  -4.466   3.526  -5.437  -0.064  -6.591  -0.039  -3.303
# 75%     1.709  -0.788  -2.447   5.224  -2.825   0.695  -4.252   0.634  -1.142
# max    20.007   3.354   4.031  12.019   1.376   2.815   3.442   2.471   3.140
#
#          v_17    v_18    v_19    v_20    v_21    v_22    v_23    v_24    v_25  \
# count 473.000 473.000 473.000 473.000 473.000 473.000 473.000 473.000 473.000
# mean   -6.463  -2.157   0.669   0.405   0.467   0.087  -0.096  -0.107   0.041
# std     6.966   2.902   1.534   1.289   2.731   1.181   1.509   0.518   0.807
# min   -25.163  -9.499  -3.682  -4.128 -22.798  -8.887 -19.254  -2.028  -4.782
# 25%   -11.589  -4.569  -0.301  -0.160   0.028  -0.522  -0.342  -0.437  -0.320
# 50%    -5.158  -1.418   0.648   0.286   0.574   0.055  -0.075  -0.061   0.078
# 75%    -1.129   0.116   1.661   0.821   1.193   0.616   0.288   0.282   0.464
# max     6.739   3.790   5.228  11.059  27.203   8.362   5.466   1.091   2.208
#
#          v_26    v_27    v_28   amount   class
# count 473.000 473.000 473.000  473.000 473.000
# mean    0.050   0.214   0.078  123.872   1.000
# std     0.463   1.246   0.533  260.211   0.000
# min    -1.153  -7.263  -1.869    0.000   1.000
# 25%    -0.263  -0.016  -0.097    1.000   1.000
# 50%     0.013   0.395   0.146    9.820   1.000
# 75%     0.396   0.821   0.372  105.890   1.000
# max     2.745   3.052   1.779 2125.870   1.000

# %%
df.groupby(df['class'])['time'].mean().plot(kind='bar')
# Out:
# <AxesSubplot: xlabel='class'>

# %%
df["hour"] = df["time"] / (60*60)
df["hour"] = df["hour"].map(lambda x: int(x))
df["hour"].describe()
# Out:
# count   283726.000
# mean        25.845
# std         13.183
# min          0.000
# 25%         15.000
# 50%         23.000
# 75%         38.000
# max         47.000
# Name: hour, dtype: float64

# %%
df["hour"] = df["hour"].map(lambda x: x-24 if x >= 24 else x)
df["hour"].describe()
# Out:
# count   283726.000
# mean        14.046
# std          5.835
# min          0.000
# 25%         10.000
# 50%         15.000
# 75%         19.000
# max         23.000
# Name: hour, dtype: float64

# %%
df["hour"].value_counts().sort_index().plot(kind= "bar")
# Out:
# <AxesSubplot: >

# %%
ax = sns.countplot(data= df[df["class"] == 1], x= "hour")
plt.title( "Number of Fraud Cases by Hours of the Day")
plt.xlabel("Hour of the Day")
plt.bar_label(ax.containers[0])
plt.show()

# %%
ax = sns.boxplot(data= df[df["class"] == 1], x= "hour", y="amount")
plt.title( "Amount Lost by Hours of the Day (Million Dollars)")
plt.xlabel("Hour of the Day")
plt.ylabel("Amount Lost in Million Dollars")
plt.show()

# %%
ax = sns.barplot(data= df[df["class"] == 1], x= "hour", y="amount", ci= None)
ax.bar_label(ax.containers[0], fontsize="small", fmt="%.0f")
plt.title( "Average Loss by Hours of the Day (Dollars)")
plt.xlabel("Hour of the Day")
plt.ylabel("Average Loss in Dollars")
plt.show()

# %%
df.groupby("daytime")["amount"].mean()
# Out:
# daytime
# 03-09-Hours   82.440
# 10-21-Hours   94.349
# 22-02-Hours   67.321
# Name: amount, dtype: float64

# %%
sns.set(style="whitegrid")
ax=df.groupby("hour")["amount"].sum().map(lambda x: x/1000000).plot(kind = "bar")
ax.bar_label(ax.containers[0], fontsize="small", fmt="%.2f")
plt.title( "Total Loss by Hours of the Day (Million Dollars)")
plt.xlabel("Hour of the Day")
plt.ylabel("Total Loss in Million Dollars")
plt.show()

# %%
ax = sns.barplot(data= df[df["class"] == 1], x= "hour", y="amount", ci= None)
plt.bar_label(ax.containers[0])
plt.show()

# %%
df.groupby(df['class'])['amount'].mean().plot(kind='bar')
# Out:
# <AxesSubplot: xlabel='class'>

# %%
df["daytime"] = df["hour"].map(lambda x:  "22-02-Hours" if x in [22,23,0,1,2] else "03-09-Hours" if x in [3,4,5,6,7,8,9] else "10-21-Hours")
df["daytime"].value_counts()
# Out:
# 10-21-Hours    196309
# 03-09-Hours     45993
# 22-02-Hours     41424
# Name: daytime, dtype: int64

# %%
# df["dayamount"] = df["hour"].map(lambda x:  "22-02" if x in [22,23,0,1,2] else "03-09" if x in [3,4,5,6,7,8,9] else "10-21")
# df["dayamount"].value_counts()

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df[["amount", "time", "class"]].corr(),linewidth=3,annot=True, cmap='BuPu')
plt.title("Correlation Matrix")
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %%
mask = np.zeros_like(df.corr(), dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

plt.figure(figsize=(40,20))
sns.heatmap(df.corr(),linewidth=3,annot=True, cmap='BuPu', mask=mask)
plt.title("Correlation Matrix")
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %%
plt.figure(figsize=(24, 12))
df.corr()['class'].drop('class').sort_values().plot.barh()
# Out:
# <AxesSubplot: >

# %%
# !pip install scipy
# Out:
# Requirement already satisfied: scipy in /Users/kadirozkan/tensorflow-metal/lib/python3.9/site-packages (1.9.1)
# Requirement already satisfied: numpy<1.25.0,>=1.18.5 in /Users/kadirozkan/tensorflow-metal/lib/python3.9/site-packages (from scipy) (1.23.3)

# %%
import scipy
from scipy import stats
from scipy.stats.stats import pearsonr
import scipy.stats as stats
import statsmodels.api as sm

# %%
from scipy.stats import f_oneway
print("The Result of One-Way ANOVA Test:")
print("====="*10)
OneWay = stats.f_oneway(df[df["daytime"] == "10-21-Hours"]["amount"],
                        df[df["daytime"] == "03-09-Hours"]["amount"],
                        df[df["daytime"] == "22-02-Hours"]["amount"],
)
OneWay
alpha = 0.05
if OneWay.pvalue < alpha:
    result = f"* The F-statistic : {OneWay.statistic} \n* The P-value of {OneWay.pvalue}. \n* Since p value is smaller than the alpha value ({alpha}), we reject the null hypothesis. \n* These findings tells us that at least one of the group means is significantly different from the rest."
else:
    result = f"* The F-statistic : {OneWay.statistic} \n* The P-value of {OneWay.pvalue}. \n* Since p value is greater than the alpha value ({alpha}), we have fail to reject the null hypothesis. \n* According to these findings, there isn't a statistically significant difference between the group means."
print(result)
# Out:
# The Result of One-Way ANOVA Test:
# ==================================================
# * The F-statistic : 215.52184576753626
# * The P-value of 2.958558596903958e-94.
# * Since p value is smaller than the alpha value (0.05), we reject the null hypothesis.
# * These findings tells us that at least one of the group means is significantly different from the rest.

# %%
from statsmodels.stats.multicomp import pairwise_tukeyhsd
print("The comparisons with p-adj values less than 0.05 have significantly different mean scores:")
print("  ")
# Perform multiple pairwise comparison (Tukey HSD)
multi_comp = pairwise_tukeyhsd(endog=df['amount'], groups=df['daytime'], alpha=0.05)
print(multi_comp)
# Out:
# The comparisons with p-adj values less than 0.05 have significantly different mean scores:
#
#       Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================================
#    group1      group2   meandiff p-adj  lower    upper   reject
# ---------------------------------------------------------------
# 03-09-Hours 10-21-Hours  11.9091   0.0   8.8712  14.9469   True
# 03-09-Hours 22-02-Hours  -15.119   0.0 -19.0912 -11.1468   True
# 10-21-Hours 22-02-Hours -27.0281   0.0 -30.1988 -23.8574   True
# ---------------------------------------------------------------

# %%
df.groupby("daytime")["amount"].mean()
# Out:
# daytime
# 03-09-Hours   82.440
# 10-21-Hours   94.349
# 22-02-Hours   67.321
# Name: amount, dtype: float64

# %% [markdown]
# At night, at 22:00 - 02:00 the average amount of credit fraud is the highest

# %% [markdown]
# ## Apply Data Integrity Checks
# * link: https://docs.deepchecks.com/stable/user-guide/tabular/auto_quickstarts/plot_quick_data_integrity.html

# %% [markdown]
# right before splitting it or using it for training

# %%
import sys
# !{sys.executable} -m pip install deepchecks -U --quiet

# %%
from deepchecks.tabular.suites import data_integrity

# Run Suite:
integ_suite = data_integrity()
suite_result = integ_suite.run(df)
# Note: the result can be saved as html using suite_result.save_as_html()
# or exported to json using suite_result.to_json()
suite_result.show()
# Out:
# deepchecks - WARNING - Received a "pandas.DataFrame" instance. It is recommended to pass a "deepchecks.tabular.Dataset" instance by initializing it with the data and metadata, for example by doing "Dataset(dataframe, label=label, cat_features=cat_features)"
# deepchecks - WARNING - It is recommended to initialize Dataset with categorical features by doing "Dataset(df, cat_features=categorical_list)". No categorical features were passed, therefore heuristically inferring categorical features in the data. 2 categorical features were inferred.: class, hour
#     <style>
#         progress {
#             -webkit-appearance: none;
#             border: none;
#             border-radius: 3px;
#             width: 300px;
#             height: 20px;
#             vertical-align: middle;
#             margin-right: 10px;
#             background-color: aliceblue;
#         }
#         progress::-webkit-progress-bar {
#             border-radius: 3px;
#             background-color: aliceblue;
#         }
#         progress::-webkit-progress-value {
#             background-color: #9d60fb;
#         }
#         progress::-moz-progress-bar {
#             background-color: #9d60fb;
#         }
#     </style>
#             <div>
#                 <label>
#                     Data Integrity Suite:<br/>
#                     <progress
#                         value='12'
#                         max='12'
#                         class='deepchecks'
#                     >
#                     </progress>
#                 </label>
#                 <span>12/12 [Time: 00:29, Check=Identifier Label Correlation]</span>
#             </div>
# Accordion(children=(VBox(children=(HTML(value='\n            <h1 id="summary_4MYRYWZYDQP81FZ722BT2YYAD">Data I…

# %% [markdown]
# Looking at the results, we observe that there is no problem with our data. It's clean.

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## 2. Data Preprocessing

# %% [markdown]
# #### Train - Test Split
#
# As in this case, for extremely imbalanced datasets you may want to make sure that classes are balanced across train and test data.

# %%
X = df.drop(columns=["class"])
y = df["class"]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, stratify=y)
X_train.shape, X_test.shape
# Out:
# ((255353, 31), (28373, 31))

# %% [markdown]
# ## Train-Test Validation Checks
# * link : https://docs.deepchecks.com/stable/user-guide/tabular/auto_quickstarts/plot_quick_train_test_validation.html

# %%
from deepchecks.tabular import Dataset

# Categorical features can be heuristically inferred, however we
# recommend to state them explicitly to avoid misclassification.

# Metadata attributes are optional. Some checks will run only if specific attributes are declared.

train_ds = Dataset(X_train)
test_ds = Dataset(X_test)
# Out:
# deepchecks - WARNING - It is recommended to initialize Dataset with categorical features by doing "Dataset(df, cat_features=categorical_list)". No categorical features were passed, therefore heuristically inferring categorical features in the data. 1 categorical features were inferred.: hour
# deepchecks - WARNING - It is recommended to initialize Dataset with categorical features by doing "Dataset(df, cat_features=categorical_list)". No categorical features were passed, therefore heuristically inferring categorical features in the data. 1 categorical features were inferred.: hour

# %%
from deepchecks.tabular.suites import train_test_validation

validation_suite = train_test_validation()
suite_result = validation_suite.run(train_ds, test_ds)
# Note: the result can be saved as html using suite_result.save_as_html()
# or exported to json using suite_result.to_json()
suite_result
# Out:
#     <style>
#         progress {
#             -webkit-appearance: none;
#             border: none;
#             border-radius: 3px;
#             width: 300px;
#             height: 20px;
#             vertical-align: middle;
#             margin-right: 10px;
#             background-color: aliceblue;
#         }
#         progress::-webkit-progress-bar {
#             border-radius: 3px;
#             background-color: aliceblue;
#         }
#         progress::-webkit-progress-value {
#             background-color: #9d60fb;
#         }
#         progress::-moz-progress-bar {
#             background-color: #9d60fb;
#         }
#     </style>
#             <div>
#                 <label>
#                     Train Test Validation Suite:<br/>
#                     <progress
#                         value='12'
#                         max='12'
#                         class='deepchecks'
#                     >
#                     </progress>
#                 </label>
#                 <span>12/12 [Time: 00:45, Check=Multivariate Drift]</span>
#             </div>
# Accordion(children=(VBox(children=(HTML(value='\n            <h1 id="summary_TRHKVO7YTWMJBAZOUS2MKY4L4">Train …

# %% [markdown]
# Looking at the results, we conclude that our data there is no meaningful difference of distributions between our train data and test data. The data is not drifted.

# %% [markdown]
# #### Scaling

# %%
# df_scaled =

# %%
from sklearn.utils import class_weight

class_weights = class_weight.compute_class_weight(class_weight = 'balanced', classes = np.unique(y_train), y = y_train)
class_weights

# %%
# StratifiedKFold
from sklearn.model_selection import StratifiedKFold

# %%
# resampling
# 1- SMOTE for imbalanced data (oversampling)
# 2- from imblearn.over_sampling import SMOTE (undersampling)
from imblearn.under_sampling import RandomUnderSampler

# %%
# SHAP API for feature selection

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## 3. Model Building
# It was previously stated that you need to make class prediction with three different algorithms. As in this case, different approaches are required to obtain better performance on unbalanced data.
#
# This dataset is severely **unbalanced** (most of the transactions are non-fraud). So the algorithms are much more likely to classify new observations to the majority class and high accuracy won't tell us anything. To address the problem of imbalanced dataset, we can use undersampling and oversampling or class weight and optimum thresold techniques.
#
# ***Note***:
#
# - *Do not forget to import the necessary libraries and modules before starting the model building!*
#
# - *If you are going to use the cross validation method to be more sure of the performance of your model for unbalanced data, you should make sure that the class distributions in the iterations are equal. For this case, you should use **[StratifiedKFold](https://www.analyseup.com/python-machine-learning/stratified-kfold.html)** instead of regular cross validation method.*

# %% [markdown]
# ### Logistic Regression
#
# - The steps you are going to cover for this algorithm are as follows:
#
#    *i. Import Libraries*
#
#    *ii. Model Training*
#
#    *iii. Prediction and Model Evaluating (Apply StratifiedKFold) and Tuning*
#
#    *iv. Plot Precision and Recall Curve*

# %% [markdown]
# ***i. Import Libraries***

# %% [markdown]
# ***ii. Model Training***

# %%
class_weights = {0:1, 1:15} #for logistic regression 1'e 15 katını vermek için 1e 20 de olabilir

# %%
log_model = LogisticRegression(class_weight=class_weights)

# %% [markdown]
# ***iii. Prediction and Model Evaluating (Apply StratifiedKFold) and Tuning***

# %% [markdown]
# You're evaluating "accuracy score"? Is your performance metric reflect real success? You may need to use different metrics to evaluate performance on unbalanced data. You should use **[precision and recall metrics](https://scikit-learn.org/stable/auto_examples/model_selection/plot_precision_recall.html#:~:text=The%20precision%2Drecall%20curve%20shows,a%20low%20false%20negative%20rate.)**.

# %% [markdown]
# ***iv. Plot Precision and Recall Curve***

# %% [markdown]
# - Didn't the performance of the model you implemented above satisfy you? If your model is biased towards the majority class and minority class matrics is not sufficient, apply "unbalanced data tecniques".

# %% [markdown]
# ***v. Apply Model Evaluation Checks***
# * link : https://docs.deepchecks.com/stable/user-guide/tabular/auto_quickstarts/plot_quick_model_evaluation.html

# %% [markdown]
# ### Logistic Regression with Unbalanced Data Techniques
#
# - The steps you are going to cover for this algorithm are as follows:
#
#    *i. Import Libraries*
#
#    *ii. Model Training*
#
#    *iii. Prediction and Model Evaluating (Apply StratifiedKFold) and Tuning*
#
#    *iv. Plot Precision and Recall Curve*

# %% [markdown]
# ***i. Train-Test Split (Again)***

# %% [markdown]
# ***ii. Model Training***

# %% [markdown]
# ***Prediction and Model Evaluating (Apply StratifiedKFold) and Tuning***

# %% [markdown]
# ***iv.  Plot Precision and Recall Curve***

# %% [markdown]
# ***v. Apply Model Evaluation Checks***
# * link : https://docs.deepchecks.com/stable/user-guide/tabular/auto_quickstarts/plot_quick_model_evaluation.html

# %% [markdown]
# ### Random Forest Classifier with Unbalanced Data Techniques
#
# - The steps you are going to cover for this algorithm are as follows:
#
#    *i. Model Training*
#
#    *ii. Prediction and Model Evaluating (Apply StratifiedKFold) and Tuning*
#
#    *iii. Plot Precision and Recall Curve*

# %% [markdown]
# ***i. Model Training***

# %% [markdown]
# ***ii. Prediction and Model Evaluating (Apply StratifiedKFold) and Tuning***

# %% [markdown]
# ***iii. Plot Precision and Recall Curve***

# %% [markdown]
# ***v. Apply Model Evaluation Checks***
# * link : https://docs.deepchecks.com/stable/user-guide/tabular/auto_quickstarts/plot_quick_model_evaluation.html

# %% [markdown]
# ### XGBoost Classifier with Unbalanced Data Techniques
#
# - The steps you are going to cover for this algorithm are as follows:
#
#    *i. Model Training*
#
#    *ii. Prediction and Model Evaluating (Apply StratifiedKFold) and Tuning*
#
#    *iii. Plot Precision and Recall Curve*

# %% [markdown]
# ***i. Model Training***

# %% [markdown]
# ***ii. Prediction and Model Evaluating (Apply StratifiedKFold) and Tuning***

# %% [markdown]
# ***iii. Plot Precision and Recall Curve***

# %% [markdown]
# ***v. Apply Model Evaluation Checks***
# * link : https://docs.deepchecks.com/stable/user-guide/tabular/auto_quickstarts/plot_quick_model_evaluation.html

# %% [markdown]
# ### Neural Network
#
# In the final step, you will make classification with Neural Network which is a Deep Learning algorithm.
#
# Neural networks are a series of algorithms that mimic the operations of a human brain to recognize relationships between vast amounts of data. They are used in a variety of applications in financial services, from forecasting and marketing research to fraud detection and risk assessment.
#
# A neural network contains layers of interconnected nodes. Each node is a perceptron and is similar to a multiple linear regression. The perceptron feeds the signal produced by a multiple linear regression into an activation function that may be nonlinear.
#
# In a multi-layered perceptron (MLP), perceptrons are arranged in interconnected layers. The input layer collects input patterns. The output layer has classifications or output signals to which input patterns may map.
#
# Hidden layers fine-tune the input weightings until the neural network’s margin of error is minimal. It is hypothesized that hidden layers extrapolate salient features in the input data that have predictive power regarding the outputs.
#
# You will discover **[how to create](https://towardsdatascience.com/building-our-first-neural-network-in-keras-bdc8abbc17f5)** your deep learning neural network model in Python using **[Keras](https://keras.io/about/)**. Keras is a powerful and easy-to-use free open source Python library for developing and evaluating deep learning models.
#
# - The steps you are going to cover for this algorithm are as follows:
#
#    *i. Import Libraries*
#
#    *ii. Define Model*
#
#    *iii. Compile Model*
#
#    *iv. Fit Model*
#
#    *v. Prediction and Model Evaluating*
#
#    *vi. Plot Precision and Recall Curve*

# %% [markdown]
# ***i. Import Libraries***

# %% [markdown]
# ***ii. Define Model***

# %% [markdown]
# ***iii. Compile Model***

# %% [markdown]
# ***iv. Fit Model***

# %% [markdown]
# ***v. Prediction and Model Evaluating***

# %% [markdown]
# ***vi. Plot Precision and Recall Curve***

# %% [markdown]
# ***v. Apply Model Evaluation Checks***
# * link : https://docs.deepchecks.com/stable/user-guide/tabular/auto_quickstarts/plot_quick_model_evaluation.html

# %% [markdown]
# ## 4. Model Deployement
# You cooked the food in the kitchen and moved on to the serving stage. The question is how do you showcase your work to others? Model Deployement helps you showcase your work to the world and make better decisions with it. But, deploying a model can get a little tricky at times. Before deploying the model, many things such as data storage, preprocessing, model building and monitoring need to be studied.
#
# Deployment of machine learning models, means making your models available to your other business systems. By deploying models, other systems can send data to them and get their predictions, which are in turn populated back into the company systems. Through machine learning model deployment, can begin to take full advantage of the model you built.
#
# Data science is concerned with how to build machine learning models, which algorithm is more predictive, how to design features, and what variables to use to make the models more accurate. However, how these models are actually used is often neglected. And yet this is the most important step in the machine learning pipline. Only when a model is fully integrated with the business systems, real values ​​can be extract from its predictions.
#
# After doing the following operations in this notebook, jump to a proper IDE and create your web app with Streamlit API.

# %% [markdown]
# ### Save and Export the Best Model

# %% [markdown]
# ### Save and Export Variables

# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___
